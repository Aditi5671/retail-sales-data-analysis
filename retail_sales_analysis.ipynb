# %% [markdown]
# # Retail Sales Data Analysis
#
# ## Project Overview
# This project analyzes supermarket sales data to understand product performance, branch revenue trends, and customer purchasing patterns.
#
# ## Tools Used
# Python
# Pandas
# NumPy
# Matplotlib
# Seaborn

# %% [markdown]
# # Data Loading and Inspection

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('supermarket.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
# 5  699-14-3026   Giza  Naypyitaw        Member  Female
# 6  355-53-5943   Alex     Yangon        Member  Female
# 7  315-22-5665   Giza  Naypyitaw        Member  Female
# 8  665-32-9167   Alex     Yangon        Member  Female
# 9  692-92-5582  Cairo   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Sales                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# # Data Cleaning and Preparation

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Sales                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df["TotalSales"]=df["Unit price"]*df["Quantity"]+df["Tax 5%"]

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Sales', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'TotalSales'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
product_sales=df.groupby("Product line")["TotalSales"].sum()
product_sales=product_sales.sort_values(ascending=False)
top_3=product_sales.head(3)
print("Top 3 Product Lines contributing most to Total Sales are:")
print(top_3)
# Out:
# Top 3 Product Lines contributing most to Total Sales are:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Name: TotalSales, dtype: float64

# %%
avg_sales=df.groupby("Branch")["TotalSales"].mean()
highest_avg=avg_sales.idxmax()
print("Branch with highest average sales:",highest_avg)
# Out:
# Branch with highest average sales: Giza

# %%
dis_customer=df["Customer type"].value_counts
print("The distribution of customer types:",dis_customer)
# Out:
# The distribution of customer types: <bound method IndexOpsMixin.value_counts of 0      Member
# 1      Normal
# 2      Normal
# 3      Member
# 4      Member
#         ...
# 995    Normal
# 996    Normal
# 997    Member
# 998    Normal
# 999    Member
# Name: Customer type, Length: 1000, dtype: object>

# %%
avg_spends=df.groupby("Customer type")["TotalSales"].mean()
highest_avg=avg_spends.idxmax()
print("Customer type with highest average spending:",highest_avg)
# Out:
# Customer type with highest average spending: Member

# %% [markdown]
# # Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.barplot(x="Product line",y="TotalSales",data=df)
plt.xlabel("Product Line")
plt.ylabel("Total Sales")
plt.title("Total Sales by Product Line")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["Branch"],y=df["TotalSales"],data=df)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["TotalSales"],bins=10)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(7,5))
corr=df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Product line",y="Sales",hue="Branch",data=df)
plt.title("Average Sales by Product Line Across Branches")
plt.show()

# %% [markdown]
# ## Key Insights
#
# • Food and Beverages contributed the highest total revenue among product categories.
# • Branch B showed the highest average sales per transaction.
# • Member customers had slightly higher spending compared to normal customers.
# • Sales were relatively balanced across branches with minor variations.
